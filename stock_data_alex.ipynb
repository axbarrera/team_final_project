# %%
import pandas as pd

# %%
data = pd.read_csv('stocks.csv')

# %%
data
# Out:
#               date   open     high      low  close    volume Name
# 0       2013-02-08  15.07  15.1200  14.6300  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.0100  14.2600  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.5100  14.1000  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.9400  14.2500  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.9600  13.1600  13.99  31879900  AAL
# 5       2013-02-15  13.93  14.6100  13.9300  14.50  15628000  AAL
# 6       2013-02-19  14.33  14.5600  14.0800  14.26  11354400  AAL
# 7       2013-02-20  14.17  14.2600  13.1500  13.33  14725200  AAL
# 8       2013-02-21  13.62  13.9500  12.9000  13.37  11922100  AAL
# 9       2013-02-22  13.57  13.6000  13.2100  13.57   6071400  AAL
# 10      2013-02-25  13.60  13.7600  13.0000  13.02   7186400  AAL
# 11      2013-02-26  13.14  13.4200  12.7000  13.26   9419000  AAL
# 12      2013-02-27  13.28  13.6200  13.1800  13.41   7390500  AAL
# ...

# %%
data_dict = {}
for i in range(0,len(data)):
    values = {}
    dates = {}
    names = {}
    date = data.iat[i,0]
    _open = data.iat[i,1]
    _close = data.iat[i,4]
    _high = data.iat[i,2]
    _low = data.iat[i,3]
    name = data.iat[i,6]
    volume = data.iat[i,5]
    values['open'] = _open
    values['close'] = _close
    values['high'] = _high
    values['low'] = _low
    if name not in data_dict:
        date_dict = {}
        values_dict = {}
        date_dict[date] = {'open':_open,'close':_close,'low':_low,'high':_high,'volume':volume}
        data_dict[name] = date_dict
    else:
        date_dict[date] = {'open':_open,'close':_close,'low':_low,'high':_high,'volume':volume}

# %%
#Get unique company names
data['Name'].unique()
# Out:
# array(['AAL', 'AAPL', 'AAP', 'ABBV', 'ABC', 'ABT', 'ACN', 'ADBE', 'ADI',
#        'ADM', 'ADP', 'ADSK', 'ADS', 'AEE', 'AEP', 'AES', 'AET', 'AFL',
#        'AGN', 'AIG', 'AIV', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK',
#        'ALLE', 'ALL', 'ALXN', 'AMAT', 'AMD', 'AME', 'AMGN', 'AMG', 'AMP',
#        'AMT', 'AMZN', 'ANDV', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APC',
#        'APD', 'APH', 'APTV', 'ARE', 'ARNC', 'ATVI', 'AVB', 'AVGO', 'AVY',
#        'AWK', 'AXP', 'AYI', 'AZO', 'A', 'BAC', 'BAX', 'BA', 'BBT', 'BBY',
#        'BDX', 'BEN', 'BF.B', 'BHF', 'BHGE', 'BIIB', 'BK', 'BLK', 'BLL',
#        'BMY', 'BRK.B', 'BSX', 'BWA', 'BXP', 'CAG', 'CAH', 'CAT', 'CA',
#        'CBG', 'CBOE', 'CBS', 'CB', 'CCI', 'CCL', 'CDNS', 'CELG', 'CERN',
#        'CFG', 'CF', 'CHD', 'CHK', 'CHRW', 'CHTR', 'CINF', 'CI', 'CLX',
#        'CL', 'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP',
#        'COF', 'COG', 'COL', 'COO', 'COP', 'COST', 'COTY', 'CPB', 'CRM',
# ...

# %%
# read in directory of txt files
import os
# for filename in os.listdir(os.getcwd()):
   # do your stuff

path = '/ETFs'

for filename in os.listdir(path):
    # do your stuff
    print(filename)

# for filename in glob.glob(os.path.join(path, '*.txt')):
    # do your stuff
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-4047b811a89e> in <module>()
#       6 path = '/ETFs'
#       7
# ----> 8 for filename in os.listdir(path):
#       9     # do your stuff
#      10     print(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/ETFs'

# %%
# loop through em 
# Echo the contents of a file
  f = open('foo.txt', 'rU')
  for line in f:   ## iterates over the lines of the file
    print line,    ## trailing , so print does not add an end-of-line char
                   ## since 'line' already includes the end-of line.
  f.close()

# %%
data[(data['Name'] == 'AMZN') & (data['date'] == '2018-01-02')].reset_index(drop=True).iat[0,1]
# Out:
# 1172.0

# %%
data_dict['AMZN']['2018-01-02']['open']
# Out:
# 1172.0

# %%
#Time to perform lookup with dictionaries
def main1():
    return data_dict['AMZN']['2018-01-02']['open']


import time
start_time = time.time()
main1()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 5.0067901611328125e-05 seconds ---

# %%
#Time to perform lookup with dataframe query as learned in class
def main2():
    return data[(data['Name'] == 'AMZN') & (data['date'] == '2018-01-02')].reset_index(drop=True).iat[0,1]

import time
start_time = time.time()
main2()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0721888542175293 seconds ---

# %%
#Get opening values for all companies on given date
def get_opening_values_with_dicts():
    for company in data['Name'].unique():
        print(company, data_dict[company]['2018-01-02']['open'])

# %%
#time to get all opening values with nested dictionaries
start_time = time.time()
get_opening_values_with_dicts()
dict_time = time.time() - start_time
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# AAL 52.33
# AAPL 170.16
# AAP 100.9
# ABBV 97.14
# ABC 92.15
# ABT 58.2
# ACN 153.5
# ADBE 175.85
# ADI 89.24
# ADM 40.2
# ADP 116.03
# ADSK 105.34
# ADS 254.29
# AEE 58.98
# AEP 73.18
# AES 10.87
# AET 180.94
# AFL 88.36
# AGN 164.05
# AIG 60.0
# AIV 43.79
# AIZ 101.44
# AJG 63.55
# AKAM 65.13
# ALB 128.93
# ALGN 222.61
# ALK 74.04
# ALLE 80.07
# ALL 104.07
# ALXN 121.63
# AMAT 51.68
# AMD 10.42
# AME 72.89
# AMGN 175.35
# AMG 206.52
# AMP 170.64
# AMT 143.16
# AMZN 1172.0
# ANDV 114.92
# ANSS 148.15
# ANTM 225.0
# AON 134.25
# AOS 61.45
# APA 42.65
# APC 54.13
# APD 164.88
# APH 88.47
# APTV 84.89
# ARE 131.0
# ARNC 27.31
# ATVI 63.54
# AVB 178.59
# AVGO 259.77
# AVY 115.15
# AWK 91.0
# AXP 99.73
# AYI 176.67
# AZO 716.54
# A 67.42
# BAC 29.75
# BAX 66.09
# BA 295.75
# BBT 50.0
# BBY 68.26
# BDX 215.09
# BEN 43.77
# BF.B 68.97
# BHF 58.12
# BHGE 31.71
# BIIB 321.15
# BK 54.27
# BLK 518.78
# BLL 38.12
# BMY 61.4
# BRK.B 198.87
# BSX 24.94
# BWA 51.38
# BXP 130.39
# CAG 37.68
# ...

# %%
def get_opening_values_with_df():
    for company in data['Name'].unique():
        print(company, data[(data['Name'] == company) & (data['date'] == '2018-01-02')].reset_index(drop=True).iat[0,1])

# %%
#time to get all opening values with dataframe
start_time = time.time()
get_opening_values_with_df()
df_time = time.time() - start_time
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# AAL 52.33
# AAPL 170.16
# AAP 100.9
# ABBV 97.14
# ABC 92.15
# ABT 58.2
# ACN 153.5
# ADBE 175.85
# ADI 89.24
# ADM 40.2
# ADP 116.03
# ADSK 105.34
# ADS 254.29
# AEE 58.98
# AEP 73.18
# AES 10.87
# AET 180.94
# AFL 88.36
# AGN 164.05
# AIG 60.0
# AIV 43.79
# AIZ 101.44
# AJG 63.55
# AKAM 65.13
# ALB 128.93
# ALGN 222.61
# ALK 74.04
# ALLE 80.07
# ALL 104.07
# ALXN 121.63
# AMAT 51.68
# AMD 10.42
# AME 72.89
# AMGN 175.35
# AMG 206.52
# AMP 170.64
# AMT 143.16
# AMZN 1172.0
# ANDV 114.92
# ANSS 148.15
# ANTM 225.0
# AON 134.25
# AOS 61.45
# APA 42.65
# APC 54.13
# APD 164.88
# APH 88.47
# APTV 84.89
# ARE 131.0
# ARNC 27.31
# ATVI 63.54
# AVB 178.59
# AVGO 259.77
# AVY 115.15
# AWK 91.0
# AXP 99.73
# AYI 176.67
# AZO 716.54
# A 67.42
# BAC 29.75
# BAX 66.09
# BA 295.75
# BBT 50.0
# BBY 68.26
# BDX 215.09
# BEN 43.77
# BF.B 68.97
# BHF 58.12
# BHGE 31.71
# BIIB 321.15
# BK 54.27
# BLK 518.78
# BLL 38.12
# BMY 61.4
# BRK.B 198.87
# BSX 24.94
# BWA 51.38
# BXP 130.39
# CAG 37.68
# ...

# %%
print('Df:Dict Lookup Ratio',df_time/dict_time)
# Out:
# Df:Dict Lookup Ratio 423.8318065472181
